# %%
import math

# %%
pi = 3.14
x, y, z = 3, 1, 2

# %%
print(round(pi))
print(math.ceil(pi))
print(math.floor(pi))
print(abs(pi))
print(pow(pi, 2))
print(math.sqrt(420))
print(max(x, y, z))
print(min(x, y, z))
# Out:
# 3
# 4
# 3
# 3.14
# 9.8596
# 20.493901531919196
# 3
# 1
