# %% [markdown]
# type casting = convert the data type of a value to another data type

# %%
x = 1    # int
y = 2.3  # double
z = "3"  # str

# %%
x = float(x)
y = int(y)
z = int(z)

print(x)
print(y)
print(z)
# Out:
# 1.0
# 2
# 3
