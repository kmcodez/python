# %%
name = input("what is your name?: ")
age = int(input("How old are you?: "))
height = float(input("How tall are you?: "))

# %%
age += 1

# %%
print("Hello " + name)
print("You are " + str(age) + " years old")
print("You are " + str(height) + "cm tall")
# Out:
# Hello kumar
# You are 26 years old
# You are 275.0cm tall
