# %% [markdown]
# tuple =   a collection which is ordered and unchangeable<br>
#           used to group together related data

# %%
student = ("Bro", 21, "male")

# %%
print(student.count("Bro"))
print(student.index("male"))
# Out:
# 1
# 2

# %%
for x in student:
    print(x)
# Out:
# Bro
# 21
# male

# %% [markdown]
# check if "Bro" is in the tuple of student

# %%
if "Bro" in student:
    print("Bro is here")
# Out:
# Bro is here
