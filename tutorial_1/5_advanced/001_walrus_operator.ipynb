# %% [markdown]
# walrus operator :=

# %% [markdown]
# new to Python 3.8<br>
# assignment expression aka walrus operator<br>
# assigns values to variables as part of a larger expression

# %% [markdown]
# case 1

# %%
happy = True
print(happy)

# %% [markdown]
# print(happy = True) # get an error with : 'happy' is an invalid keyword argument for print()

# %% [markdown]
# you can also do the same thing as the code above by

# %%
print(happy := True)

# %% [markdown]
# case 2

# %%
foods = list()
while True:
    food = input("What food do you like?:")
    if food == "quit":
        break
    foods.append(food)

# %%
foods = list()
while food := input("What food do you like?: "):
    if food == "quit":
        break
    foods.append(food)
print("foods: ", foods)
